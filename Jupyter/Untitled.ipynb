# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
# 1. Определить корни
# 2. Найти интервалы, на которых функция возрастает
# 3. Найти интервалы, на которых функция убывает
# 4. Построить график
# 5. Вычислить вершину
# 6. Определить промежутки, на котором f > 0
# 7. Определить промежутки, на котором f < 0

# %%
from sympy import *

# %%
x = Symbol('x')

# %%
y = -12*(x**4)*sin(cos(x)) - 18*(x**3)+5*(x**2) + 10*x - 30

# %%
y
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
plot(y)

# %%
solve(y,x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16472\3529240630.py in <module>
# ----> 1 solve(y,x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1104     ###########################################################################
#    1105     if bare_f:
# -> 1106         solution = _solve(f[0], *symbols, **flags)
#    1107     else:
#    1108         solution = _solve_system(f, symbols, **flags)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1710         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1711         try:
# -> 1712             soln = _tsolve(f_num, symbol, **flags)
#    1713             if soln is not None:
#    1714                 result = soln
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2683         rewrite = lhs.rewrite(exp)
#    2684         if rewrite != lhs:
# -> 2685             return _solve(rewrite - rhs, sym, **flags)
#    2686     except NotImplementedError:
#    2687         pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1710         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1711         try:
# -> 1712             soln = _tsolve(f_num, symbol, **flags)
#    1713             if soln is not None:
#    1714                 result = soln
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2564             f = factor(powdenest(lhs - rhs))
#    2565             if f.is_Mul:
# -> 2566                 return _solve(f, sym, **flags)
#    2567             if rhs:
#    2568                 f = logcombine(lhs, force=flags.get('force', True))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1392                 result = set()
#    1393                 break
# -> 1394             soln = _solve(m, symbol, **flags)
#    1395             result.update(set(soln))
#    1396         result = list(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1710         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1711         try:
# -> 1712             soln = _tsolve(f_num, symbol, **flags)
#    1713             if soln is not None:
#    1714                 result = soln
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2753         if pos.has(u):
#    2754             try:
# -> 2755                 soln = _solve(pos, u, **flags)
#    2756                 return list(ordered([s.subs(reps) for s in soln]))
#    2757             except NotImplementedError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1710         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1711         try:
# -> 1712             soln = _tsolve(f_num, symbol, **flags)
#    1713             if soln is not None:
#    1714                 result = soln
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2562             # it's time to try factoring; powdenest is used
#    2563             # to try get powers in standard form for better factoring
# -> 2564             f = factor(powdenest(lhs - rhs))
#    2565             if f.is_Mul:
#    2566                 return _solve(f, sym, **flags)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polytools.py in factor(f, deep, *gens, **args)
#    6451
#    6452     try:
# -> 6453         return _generic_factor(f, gens, args, method='factor')
#    6454     except PolynomialError as msg:
#    6455         if not f.is_commutative:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polytools.py in _generic_factor(expr, gens, args, method)
#    6132     opt = options.build_options(gens, args)
#    6133     opt['fraction'] = fraction
# -> 6134     return _symbolic_factor(sympify(expr), opt, method)
#    6135
#    6136
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polytools.py in _symbolic_factor(expr, opt, method)
#    6072         if hasattr(expr,'_eval_factor'):
#    6073             return expr._eval_factor()
# -> 6074         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6075         return _keep_coeff(coeff, _factors_product(factors))
#    6076     elif hasattr(expr, 'args'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polytools.py in _symbolic_factor_list(expr, opt, method)
#    6037             func = getattr(poly, method + '_list')
#    6038
# -> 6039             _coeff, _factors = func()
#    6040             if _coeff is not S.One:
#    6041                 if exp.is_Integer:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polytools.py in factor_list(f)
#    3351         if hasattr(f.rep, 'factor_list'):
#    3352             try:
# -> 3353                 coeff, factors = f.rep.factor_list()
#    3354             except DomainError:
#    3355                 return S.One, [(f, 1)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polyclasses.py in factor_list(f)
#     821     def factor_list(f):
#     822         """Returns a list of irreducible factors of ``f``. """
# --> 823         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     824         return coeff, [ (f.per(g), k) for g, k in factors ]
#     825
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_factor_list(f, u, K0)
#    1389         coeff, factors = dmp_ext_factor(f, u, K0)
#    1390     elif K0.is_GaussianRing:
# -> 1391         coeff, factors = dmp_zz_i_factor(f, u, K0)
#    1392     elif K0.is_GaussianField:
#    1393         coeff, factors = dmp_qq_i_factor(f, u, K0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_i_factor(f, u, K0)
#    1204     K1 = K0.get_field()
#    1205     f = dmp_convert(f, u, K0, K1)
# -> 1206     coeff, factors = dmp_qq_i_factor(f, u, K1)
#    1207
#    1208     new_factors = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_qq_i_factor(f, u, K0)
#    1193     K1 = K0.as_AlgebraicField()
#    1194     f = dmp_convert(f, u, K0, K1)
# -> 1195     coeff, factors = dmp_factor_list(f, u, K1)
#    1196     factors = [(dmp_convert(fac, u, K1, K0), i) for fac, i in factors]
#    1197     coeff = K0.convert(coeff, K1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_factor_list(f, u, K0)
#    1387         coeff, factors = dmp_gf_factor(f, u, K0)
#    1388     elif K0.is_Algebraic:
# -> 1389         coeff, factors = dmp_ext_factor(f, u, K0)
#    1390     elif K0.is_GaussianRing:
#    1391         coeff, factors = dmp_zz_i_factor(f, u, K0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_ext_factor(f, u, K)
#    1263         return lc, []
#    1264
# -> 1265     f, F = dmp_sqf_part(f, u, K), f
#    1266     s, g, r = dmp_sqf_norm(f, u, K)
#    1267
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\sqfreetools.py in dmp_sqf_part(f, u, K)
#     254     gcd = f
#     255     for i in range(u+1):
# --> 256         gcd = dmp_gcd(gcd, dmp_diff_in(f, 1, i, u, K), u, K)
#     257     sqf = dmp_quo(f, gcd, u, K)
#     258
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1622
#    1623     """
# -> 1624     return dmp_inner_gcd(f, g, u, K)[0]
#    1625
#    1626
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1581
#    1582     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1583     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1584
#    1585     return (dmp_inflate(h, J, u, K),
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1546                 pass
#    1547
# -> 1548         return dmp_ff_prs_gcd(f, g, u, K)
#    1549     else:
#    1550         if K.is_ZZ and query('USE_HEU_GCD'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_ff_prs_gcd(f, g, u, K)
#    1111     gc, G = dmp_primitive(g, u, K)
#    1112
# -> 1113     h = dmp_subresultants(F, G, u, K)[-1]
#    1114     c, _, _ = dmp_ff_prs_gcd(fc, gc, u - 1, K)
#    1115
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_subresultants(f, g, u, K)
#     548
#     549     """
# --> 550     return dmp_inner_subresultants(f, g, u, K)[0]
#     551
#     552
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_subresultants(f, g, u, K)
#     511                     dmp_pow(c, d, v, K), v, K)
#     512
# --> 513         h = dmp_prem(f, g, u, K)
#     514         h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_prem(f, g, u, K)
#    1236
#    1237         R = dmp_mul_term(r, lc_g, 0, u, K)
# -> 1238         G = dmp_mul_term(g, lc_r, j, u, K)
#    1239         r = dmp_sub(R, G, u, K)
#    1240
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_mul_term(f, c, i, u, K)
#     182         return dmp_zero(u)
#     183     else:
# --> 184         return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#     185
#     186
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     182         return dmp_zero(u)
#     183     else:
# --> 184         return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#     185
#     186
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_mul(f, g, u, K)
#     826
#     827         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     829
#     830         h.append(coeff)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_mul(f, g, u, K)
#     826
#     827         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     829
#     830         h.append(coeff)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_mul(f, g, u, K)
#     826
#     827         for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828             coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     829
#     830         h.append(coeff)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_mul(f, g, u, K)
#     805     """
#     806     if not u:
# --> 807         return dup_mul(f, g, K)
#     808
#     809     if f == g:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dup_mul(f, g, K)
#     765
#     766             for j in range(max(0, i - dg), min(df, i) + 1):
# --> 767                 coeff += f[j]*g[i - j]
#     768
#     769             h.append(coeff)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polyclasses.py in __mul__(f, g)
#    1737     def __mul__(f, g):
#    1738         if isinstance(g, ANP):
# -> 1739             return f.mul(g)
#    1740         else:
#    1741             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\polyclasses.py in mul(f, g)
#    1648     def mul(f, g):
#    1649         dom, per, F, G, mod = f.unify(g)
# -> 1650         return per(dup_rem(dup_mul(F, G, dom), mod, dom))
#    1651
#    1652     def pow(f, n):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dup_rem(f, g, K)
#    1555
#    1556     """
# -> 1557     return dup_div(f, g, K)[1]
#    1558
#    1559
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dup_div(f, g, K)
#    1532     """
#    1533     if K.is_Field:
# -> 1534         return dup_ff_div(f, g, K)
#    1535     else:
#    1536         return dup_rr_div(f, g, K)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dup_ff_div(f, g, K)
#    1429     if not g:
#    1430         raise ZeroDivisionError("polynomial division")
# -> 1431     elif df < dg:
#    1432         return q, r
#    1433
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     234             if not isinstance(other, expectedcls):
#     235                 return retval
# --> 236             return func(self, other)
#     237
#     238         return _func
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in __lt__(self, other)
#     368     def __lt__(self, other):
#     369         from .relational import StrictLessThan
# --> 370         return StrictLessThan(self, other)
#     371
#     372     def __trunc__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\relational.py in __new__(cls, lhs, rhs, **options)
#     843             # exception).  In that case, it must call us with
#     844             # `evaluate=False` to prevent infinite recursion.
# --> 845             return cls._eval_relation(lhs, rhs, **options)
#     846
#     847         # make a "non-evaluated" Expr for the inequality
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\relational.py in _eval_relation(cls, lhs, rhs, **options)
#     850     @classmethod
#     851     def _eval_relation(cls, lhs, rhs, **options):
# --> 852         val = cls._eval_fuzzy_relation(lhs, rhs)
#     853         if val is None:
#     854             return cls(lhs, rhs, evaluate=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\relational.py in _eval_fuzzy_relation(cls, lhs, rhs)
#    1177     @classmethod
#    1178     def _eval_fuzzy_relation(cls, lhs, rhs):
# -> 1179         return is_lt(lhs, rhs)
#    1180
#    1181     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\relational.py in is_lt(lhs, rhs, assumptions)
#    1256     See the docstring for :func:`~.is_ge` for more.
#    1257     """
# -> 1258     return fuzzy_not(is_ge(lhs, rhs, assumptions))
#    1259
#    1260
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\relational.py in is_ge(lhs, rhs, assumptions)
#    1373         raise TypeError("Can only compare inequalities with Expr")
#    1374
# -> 1375     retval = _eval_is_ge(lhs, rhs)
#    1376
#    1377     if retval is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\multipledispatch\dispatcher.py in __call__(self, *args, **kwargs)
#     230
#     231     def __call__(self, *args, **kwargs):
# --> 232         types = tuple([type(arg) for arg in args])
#     233         try:
#     234             func = self._cache[types]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\multipledispatch\dispatcher.py in <listcomp>(.0)
#     230
#     231     def __call__(self, *args, **kwargs):
# --> 232         types = tuple([type(arg) for arg in args])
#     233         try:
#     234             func = self._cache[types]
#
# KeyboardInterrupt:
